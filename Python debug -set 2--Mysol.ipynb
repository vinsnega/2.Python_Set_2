# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))
#answer python case sensitive already imported math function here in prit statement capital M is used

# %%
#correct code
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
#x is not defined as global so we cant call x variable outside
def my_function():
    global x
    x+=5
    print(x)

# %%
x=10
my_function()
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")
    
#for comparing == is used

# %%
x=5
if x==10:
    print("x is 10")

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

#.sort() modifies in place and returns none

# %%
numbers=[5,3,8,2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))
# no return value is used

# %%
def square(n):
    a=n*n
    return a

# %%
print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
#tuples are immutable and cannot be modified

# %%
#sol 
mynew_tuple=(1,5,3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
name="Alice"
age=25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")
# is operator checks obeject identity not value

# %%
a=[1,2,3]
b=[1,2,3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)
# the ending range value is less than the starting value so error occurs

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
#name is mentioned as string but here give as variable

# %%
student={"name":"john", "age" :20}
print(student["name"])
# Out:
# john
